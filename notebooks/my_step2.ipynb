# %% [markdown]
# # Step 2 - 1D nonlinear convection

# %% [markdown]
# #### Differential equation to be solved

# %% [markdown]
# Solve equation
#
# $$
# \frac{\partial u(t, x)}{\partial t} + u(t, x) \, \frac{\partial u(t, x)}{\partial x} = 0
# $$
#
# by using forward differences in time and backward differences in space:

# %% [markdown]
# $$
# \frac{\partial u(t, x)}{\partial t} \approx \frac{u^{n+1}_{i} - u^{n}_{i}}{\Delta t} \quad ,
# $$

# %% [markdown]
# $$
# \frac{\partial u(t, x)}{\partial x} \approx \frac{u^{n}_{i} - u^{n}_{i-1}}{\Delta x} \quad ,
# $$

# %% [markdown]
# where $u^{n}_{i} \equiv u(t_{n}, x_{i})$. The resulting discrete equation is:
#
# $$
# u^{n+1}_{i} = u^{n}_{i} - u^{n}_{i} \, \frac{\Delta t}{\Delta x} \left( u^{n}_{i} - u^{n}_{i-1} \right) \quad .
# $$

# %% [markdown]
# #### Initial conditions

# %% [markdown]
# At $t = 0$,
#
# $
# u(t = 0, x) = u_{0}(x) \quad ,
# $
#
# where
#
# $u_{0}(x) = 2$ for $0.5 \le x \le 1$
#
# and
#
# $u_{0}(x) = 1$ everywhere else in $(0, 2)$ .

# %% [markdown]
# #### Boundary conditions

# %% [markdown]
# $u = 1$ at $x = 0$ and $x = 2$ .

# %% [markdown]
# ### Import required stuff

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Implementation

# %%
def nonlinear_convection_1D(u0, dt, nt, dx, nx):
    
    u = np.copy(u0)
    
    cte = dt/dx

    # loop in time
    for n in range(nt):
        un = u.copy()
        # loop in space
        for i in range(1, nx): # iterate from 1 to nx
            u[i] = un[i] - cte * un[i] * (un[i] - un[i-1])
    
    return u

# %%
nt = 100
dt = 0.005

nx = [20, 40, 60, 80, 100, 120]
u = []
x = []
u0 = []

for nxi in nx:
    dx = 2/(nxi - 1)
    u0i = np.ones(nxi)
    u0i[int(0.5/dx):int(1/dx)+1] = 2
    u0.append(u0i)
    u.append(nonlinear_convection_1D(u0i, dt, nt, dx, nxi))
    x.append(np.linspace(0, 2, nxi))

# %%
plt.figure(figsize=(12,8))

for i, (nxi, xi, u0i, ui) in enumerate(zip(nx, x, u0, u)):

    plt.subplot(2,3,i+1)
    plt.title('nx = %d' % (nxi))
    plt.plot(xi, u0i, '-b')
    plt.plot(xi, ui, '--r')
    plt.grid()

plt.tight_layout()
plt.show()
